# %%
import requests

# %%
r = requests.get(url="http://www.bing.com")

# %%
r.content
# Out:
# b'<!DOCTYPE html><html lang="zh"><script type="text/javascript" >//<![CDATA[\r\nsi_ST=new Date\r\n//]]></script><head><link id="bgLink" rel="preload" href="/th?id=OHR.PortuairkBay_ZH-CN5255529820_1920x1080.jpg&amp;rf=LaDigue_1920x1080.jpg&amp;pid=hp" as="image" /><link rel="preload" href="/sa/simg/hpc27.png" as="image" /><meta content="text/html; charset=utf-8" http-equiv="content-type"/><script type="text/javascript">//<![CDATA[\n/*!DisableJavascriptProfiler*/\r\n0;\r\n;/*!DisableJavascriptProfiler*/\n0;/*!DisableJavascriptProfiler*/\r\n0;\r\n;_G={Region:"CN",Lang:"zh-CN",ST:(typeof si_ST!==\'undefined\'?si_ST:new Date),Mkt:"zh-CN",RevIpCC:"cn",RTL:false,Ver:"27",IG:"B233C7DCB4A843A48F197792EF0996D8",EventID:"F5F29A6C7F0B47C5B5FD6AB0BCBE3848",V:"homepage",P:"SERP",DA:"HKGE01",CID:"1265F0FF5E9766B53A06E0985FDD6771",SUIH:"ueS1kv8PlE5Nk7Sla7hwPQ",adc:"b_ad",EF:{bmasynctrigger:1},gpUrl:"\\/fd\\/ls\\/GLinkPing.aspx?" }; _G.lsUrl="/fd/ls/l?IG="+_G.IG+"&CID="+_G.CID ;curUrl="http:\\/\\/cn.
# ...
